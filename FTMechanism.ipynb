# %% [markdown]
# <a href="https://colab.research.google.com/github/mansheik/CV/blob/main/FTMechanism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from collections import Counter
import re

# Raw multiline string of the data
data = """
Elastic scalability, Asynchronous communication and Parameter recovery 	[43]
Checkpointing	[63]
Checkpointing	[59]
Checkpointing	[77]
Checkpointing	[48]
Replication	[47]
Replication	[46]
Replication	[92]
Three-stage active-backup mechanism	[45]
Redundant Computing	[69]
Network Redundancy	[65]
State Persistence	[58]
FreeLauncher (FLR): A lossless ultralight replication	[72]
Redundant Computing	[60]
Replication	[65]
Redundant Computing	[93]
Supports basic recovery during training and inference	[85]
Hierarchical Topology (HT) with Group Selection Algorithm (GSA)	[87]
Partial Experts Checkpointing	[130]
Dynamic, adaptive, asynchronous federated learning algorithm	[125]
Redundant Computing	[101]
ECRec: Combines erasure coding with selective replication of parameters	[90]
Checkpointing	[112]
Weibull-based checkpointing, 	[151]
Redundant Computing	[114]
Stateful DL container checkpointing	[124]
Checkpointing	[129]
In-memory checkpointing	[131]
Checkpointing	[137]
FRIM (Failure-Resilient Inference in Mobile networks)	[144]
Dynamic rebalancing with temporary randomized pipelines	[95]
gossip-based communication	[59]
PPM-HDA framework with MHDA+ and MHDA schemes	[142]
Gradient Coding	[132]
Geometric median of means gradient aggregation	[143]
Gradient Coding	[ 53]
Robust Aggregation	[75]
Robust Aggregation	[62]
Robust Aggregation	[74]
Robust Aggregation	[64]
robust geometric and statistical techniques (DMC, MDA)	[82]
Elastic deep learning framework (EDL-Dist)	[83]
Robust Aggregation via Convex Optimization	[104]
Robust Aggregation	[96]
Robust Aggregation using High-Dimensional Mean Estimation	[120]
Compression + Sign	[54]
Robust Aggregation	[108]
Robust Aggregation	[126]
Gradient Filtering via Descent Score Validation	[127]
Robust Aggregation	[132]
Robust Aggregation	[133]
Hybrid Redundancy + Robust Aggregation	[135]
Robust Aggregation	[141]
Replication	[70]
Redundant Computing	[68]
Redundant Computing	[80]
Replication	[64]
Gradient Coding	[78]
Replication	[52]
Gradient Coding	[91]
Replication	[55]
Redundant Computing	[57]
Redundant Computing	[107]
Replication	[99]
Redundant Computing	[100]
Replication	[89]
Replication	[106]
Redundant Computing	[107]
Replication	[113]
Redundant Computing	[105]
Replication	[118]
synchronization delays, Parameter communication prediction	[102]
Dynamic Redundant Gradient Coding (DRGC)	[88]
Adaptive straggler mitigation	[103]
Adaptive Client Selection with Fault Tolerance	[152]
Locality-based coded computation	[109]
Optimized storage acceleration architecture	[110]
Dynamic, on-the-fly communication scheduling, fine-grained pipelining	[71]
Leverages ULFM MPI for lightweight fault recovery	[84]
Redundant Computing	[51]
In-Memory Checkpointing 	[134]
Redundant Computing	[136]
Unblocking Checkpointing	[138]
Redundant Computing	[139]
Design Principles & Algorithmic Resilience	[140]
Checkpoint/Restart (Rollback-Recovery)	[145]
in-memory updates and RDMA (Remote Direct Memory Access)	[44]
Structured dispatching and balanced load	[50]
Lineage-based recovery, dynamic resource allocation, and hybrid stream-batch pipelining	[147]
Built-in fault tolerance through automatic parallelization 	[58]
Lightweight synchronous checkpointing 	[94]
Gradient Coding	[67]
Hybrid adaptive model	[148]
NFRT with HE/Mask-based protocols, Verifiability, Secure Aggregation	[115]
Gradient compression	[66]
Redundant Computing	[163]
Replication	[97]
Replication	[98]
Redundant Computing	[86]
Replication	[111]
Redundant Computing	[121]
Proactive Fault Prediction + Importance-Aware Selective Replication	[123]
Replication	[128]
Layer Ensemble Averaging (LEA)	[150]
Comparative benchmarking of data, model, and pipeline parallelism	[149]
vRDMA (virtual RDMA) abstraction + multi-NIC redundancy	[116]
Deep learning-based fault inference	[146]
Replication	[73]
Replication	[61]
Replication	[119]
Optimization-based Mitigation	[117]
Enhanced Checkpointing / Resilient Training Strategies	[92]
"""

# Extract mechanisms using regex
mechanisms = re.findall(r'^(.*?)\s+\[\d+\]', data, re.MULTILINE)

# Count frequencies
mechanism_counts = Counter(mechanisms)

# Sort by frequency
sorted_mechanisms = sorted(mechanism_counts.items(), key=lambda x: x[1], reverse=True)
labels, counts = zip(*sorted_mechanisms)

# Plotting
plt.figure(figsize=(12, 8))
plt.barh(labels, counts, color='skyblue')
plt.xlabel('Frequency of Studies')
plt.title('Histogram of Fault Tolerance Mechanisms in DML Studies')
plt.gca().invert_yaxis()  # Most frequent on top
plt.tight_layout()
plt.show()
